nis2008_1_m1_guess = [[8711, 8416, 8492, 8425, 8381, 7992, 8445, 8195, 8272, 8444, 7772, 8424]]
nis2008_2_m1_guess = [[8735, 8540, 8543, 8399, 8388, 8141, 8408, 8075, 8154, 8354, 7812, 8408]]
nis2008_3_m1_guess = [[8852, 8352, 8498, 8342, 8255, 7951, 8501, 8464, 8310, 8420, 7709, 8259]]
nis2008_4_m1_guess = [[8935, 8478, 8718, 8314, 8395, 7948, 8374, 8111, 8154, 8320, 7763, 8320]]
nis2008_5_m1_guess = [[8674, 8528, 8404, 8242, 8284, 8188, 8491, 8192, 8321, 8444, 7786, 8383]]
nis2008_6_m1_guess = [[8768, 8312, 8553, 8284, 8314, 8210, 8497, 8231, 8305, 8401, 7690, 8280]]
nis2008_7_m1_guess = [[8802, 8310, 8578, 8365, 8228, 7993, 8542, 8130, 8134, 8391, 7638, 8306]]
nis2008_8_m1_guess = [[8775, 8352, 8643, 8360, 8249, 8102, 8438, 8176, 8380, 8328, 7748, 8321]]
nis2008_9_m1_guess = [[8833, 8464, 8511, 8434, 8409, 7987, 8520, 8229, 8173, 8368, 7741, 8331]]
nis2008_10_m1_guess =[[8777, 8337, 8652, 8270, 8182, 8080, 8439, 8172, 8269, 8343, 7616, 8340]]

# %%
# Noise m2
# Match & Extend with Noise Budget 0.002

nis2008_1_m2_guess = [[7730, 8418, 8385, 8419, 7958, 8361, 8420, 7958, 8371, 8384, 7730, 8397]]
nis2008_2_m2_guess = [[8368, 7778, 8318, 8083, 8051, 8358, 8113, 8350, 8367, 16092, 864, 8700]]
nis2008_3_m2_guess = [[7619, 8280, 8436, 8450, 8209, 7936, 8427, 8232, 8426, 8438, 7671, 8226]]
nis2008_4_m2_guess = [None]
nis2008_5_m2_guess = [[8647, 8499, 8354, 8240, 8215, 8151, 8481, 8139, 8292, 8422, 7752, 8355]]
nis2008_6_m2_guess = [[8762, 8301, 8475, 8299, 8272, 8195, 8466, 8175, 8301, 8386, 7681, 8260]]
nis2008_7_m2_guess = [[8799, 8356, 8547, 8386, 8199, 8004, 8543, 8126, 8159, 8353, 7647, 8340]]
nis2008_8_m2_guess = [[8325, 7710, 8306, 8329, 8195, 8387, 8088, 8194, 8304, 16049, 905, 8757]]
nis2008_9_m2_guess = [[8796, 8413, 8466, 8359, 8364, 7952, 8465, 8190, 8123, 8311, 7703, 8278]]
nis2008_10_m2_guess =[None]

# %%
def construct_A(N, num_nodes):
    # Construct Basic Matrix of ranges 
    A_temp = []
    for i in range(N):
        for j in range(i,N):
            temp = [0 for _ in range(num_nodes)]
            for k in range(i,j+1):
                temp[k] = 1
            A_temp.append(temp)
    A_temp = matrix(A_temp)

    # Reorder matrix and v_list
    temp_size = num_nodes
    A = []
    
    # The rows with elementary volumes
    if N == 5:
        nodes = [0,5,9,12,14]
    elif N == 10:
        nodes = [0,10,19,27,34,40,45,49,52,54]
    elif N == 12:
        nodes = [0,12,23,33,42,50,57,63,68,72,75,77]
    elif N == 15:
        nodes = [0,15,29,42,54,65,75,84,92,99,105,110,114,117,119]
        
    all_nodes = [i for i in range(num_nodes)]
    set_nodes = set(nodes)
    set_all_nodes = set(all_nodes)
    diff_nodes = list(set_all_nodes - set_nodes)

    for i in nodes:
        A.append(list(list(A_temp[i,:temp_size])[0]))
    for i in range(temp_size-N):
        A.append(list(list(A_temp[diff_nodes[i],:temp_size])[0]))

    big_num = 10**6
    idx_big_num = N
    for i in range(N,temp_size):
        A[i][idx_big_num] = big_num
        idx_big_num += 1
    A = matrix(A)

    return A


def get_closest_vols(val, vols):
    min_dist = max(vols)
    res = 0
    for i in vols:
        ratio = abs(float((i-val)/i))
        if ratio < min_dist:
            min_dist = ratio
            res = i
    return int ((1.001) * res)


def get_vlist(elem_vols, vols):
    res = []
    for i in range(N):
        for j in range(i,N):
            temp = 0
            for k in range(i,j+1):
                temp += elem_vols[k]
            res.append(get_closest_vols(temp, vols))   
    return res


def construct_v(v_list, N, num_nodes):
    v = []
    for val in v_list:
        v.append(int(val))
    v = vector(v)

    temp_size = num_nodes

    if N == 5:
        nodes = [0,5,9,12,14]
    elif N == 10:
        nodes = [0,10,19,27,34,40,45,49,52,54]
    elif N == 12:
        nodes = [0,12,23,33,42,50,57,63,68,72,75,77]
    elif N == 15:
        nodes = [0,15,29,42,54,65,75,84,92,99,105,110,114,117,119]

    all_nodes = [i for i in range(num_nodes)]
    set_nodes = set(nodes)
    set_all_nodes = set(all_nodes)
    diff_nodes = list(set_all_nodes - set_nodes)
    v_ordered = []
    for i in nodes:
        v_ordered.append(v[i])

    for i in range(temp_size-N):
        v_ordered.append(v[diff_nodes[i]])

    return v_ordered


# Given an array of size n, computes the volumes of all the ranges
# output sizeL n(n-1)/2 + n
def range_computer(arr, with_noise = False):
    n = len(arr)
    # print('input length:', n)

    output = []
    sum = 0
    for i in range(n):
        sum = arr[i]
        output.append(sum)
        if with_noise:
            output.append(sum-1)
            output.append(sum+1)
        for j in range(1,n-i):
            sum += arr[i+j]
            output.append(sum)
            if with_noise:
                output.append(sum-1)
                output.append(sum+1)
    output.sort()

    # print('ouput length:', len(output))
    return output

def sol_diff(real, guess):
    a = np.array(real)
    b = np.array(guess)
    c = (a - b) / b
    return vector(c).norm()

# %%
N = 12
num_nodes = N * (N+1) / 2


A = construct_A(N, num_nodes)
B = IntegerMatrix(num_nodes, num_nodes)
B.set_matrix(A.transpose())

import pdb
#mode = ['','_non_uniform_q','_gauss']
mode = ['_m2']
for m in mode:
    print('.\n')
    for i in range(10):
        guess_sol_name = 'nis2008_{}{}_guess'.format(i+1,m)
        guess_vol_name = 'nis2008_{}{}_vols'.format(i+1,m)
        db_name = 'db_nis2008_{}{}'.format(i+1,m)

        guess_sol = eval(guess_sol_name)[0]
        if guess_sol == None:
            print('None' + ';' + 'None')
            continue
        guess_vol = eval(guess_vol_name)
        db_ = eval(db_name)

        #pdb.set_trace()
        v_list = get_vlist(guess_sol, guess_vol)
        v_temp = construct_v(v_list, N, num_nodes)
        cvp_res = CVP.closest_vector(B, v_temp)

        cvp_diff = [db_[i]-cvp_res[i] for i in range(12)]

        #sol1_norm = sol_diff(db_, guess_sol)
        #sol2_norm = sol_diff(db_, cvp_res[:12])

        print(str(list(cvp_res[:12])) + ';' + str(list(cvp_diff)))
# Out:
# .
#
# [7233, 8433, 8397, 8432, 7932, 8398, 8430, 7956, 8386, 8394, 7810, 7792];[1488, -31, 99, 21, 461, -400, 11, 238, -118, 59, -39, 618]
# [7738, 7838, 8325, 8077, 8076, 8368, 8115, 8360, 8369, 16321, 662, 7994];[1000, 696, 217, 334, 317, -218, 300, -273, -206, -7964, 7153, 401]
# [7156, 8293, 8429, 8462, 8209, 7957, 8430, 8232, 8446, 8430, 7720, 7664];[1710, 69, 82, -107, 56, 6, 61, 237, -123, -3, -13, 597]
# None;None
# [8529, 8512, 8361, 8251, 8217, 8160, 8493, 8148, 8302, 8424, 7757, 8236];[150, 21, 40, 38, 35, 21, 24, 44, 17, 39, 28, 153]
# [8124, 8311, 8491, 8301, 8277, 8205, 8478, 8177, 8308, 8399, 7686, 7633];[658, 15, 63, 16, 17, 27, 26, 39, 30, 38, 19, 662]
# [8161, 8364, 8554, 8394, 8206, 8014, 8551, 8134, 8169, 8353, 7653, 7706];[699, 0, 70, 35, 37, 39, 40, 39, 40, 43, 32, 667]
# [7689, 7791, 8313, 8341, 8193, 8384, 8105, 8208, 8311, 16278, 691, 8052];[1102, 584, 336, -5, 63, -271, 349, -22, 82, -7942, 7068, 300]
# ...

# %%
N = 12
num_nodes = N * (N+1) / 2


A = construct_A(N, num_nodes)
B = IntegerMatrix(num_nodes, num_nodes)
B.set_matrix(A.transpose())

import pdb
#mode = ['','_non_uniform_q','_gauss']
mode = ['_noise8']
for m in mode:
    for j in range(10):
        print('.\n')
        for i in range(10):
            #pdb.set_trace()
            guess_sol_name = 'nis2008_{}{}_{}_guess'.format(i+1,m,j+1)
            guess_vol_name = 'nis2008_{}{}_{}_vols'.format(i+1,m, j+1)
            db_name = 'db_nis2008_{}'.format(i+1)

            guess_sol = eval(guess_sol_name)[0]
            if guess_sol == None:
                print('None' + '\t' + 'None')
                continue
            guess_vol = eval(guess_vol_name)
            db_ = eval(db_name)

            #pdb.set_trace()
            v_list = get_vlist(guess_sol, guess_vol)
            v_temp = construct_v(v_list, N, num_nodes)
            cvp_res = CVP.closest_vector(B, v_temp)

            cvp_diff = [db_[i]-cvp_res[i] for i in range(12)]

            #sol1_norm = sol_diff(db_, guess_sol)
            #sol2_norm = sol_diff(db_, cvp_res[:12])

            print(str(list(cvp_res[:12])) + '\t' + str(list(cvp_diff)))
